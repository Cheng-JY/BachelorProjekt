# %% [markdown]
# # Crowd Layer

# %% [markdown]
# In this brief tutorial, we show an example use-case of our package `skactiveml` with the Python package [skorch](https://skorch.readthedocs.io/en/stable/), which is a scikit-learn wrapper for Pytorch models. This way, we are able to implement and test deep learning models in combination with query strategies implemented in our framework.

# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
import numpy as np
import torch
import warnings

from sklearn.metrics import accuracy_score
from torch import nn
import torch.nn.functional as F
from torch.nn import CrossEntropyLoss

mlp.rcParams["figure.facecolor"] = "white"

MISSING_LABEL = -1
RANDOM_STATE = 0
FONTSIZE = 12

np.random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)
torch.cuda.manual_seed(RANDOM_STATE)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading Music Data Set

# %%
data_dir = "./music-multi-annotator-dataset"

# %%
X_train = np.load(f'{data_dir}/music-X.npy')
y_train = np.load(f'{data_dir}/music-y.npy')
y_train_true = np.load(f'{data_dir}/music-y-true.npy')
X_valid = np.load(f'{data_dir}/music-X-valid.npy')
y_valid = np.load(f'{data_dir}/music-y-true-valid.npy')
X_test = np.load(f'{data_dir}/music-X-test.npy')
y_test_true = np.load(f'{data_dir}/music-y-true-test.npy')

dataset_classes = np.unique(y_test_true)
n_classes = len(dataset_classes)
n_features = X_train.shape[1]
print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(X_test.shape)
# Out:
# (700, 124)
# (700, 44)
# (50, 124)
# (250, 124)

# %% [markdown]
# ## Neural Network Ensemble for tabular data set
# In the next step, we define a neural network ensemble for tabular data set

# %%
# Define base module.
class ClassifierModule(nn.Module):
    def __init__(self, n_classes, dropout):
        super(ClassifierModule, self).__init__()
        n_hidden_neurons = 128
        self.embed_X_block = nn.Sequential(
            nn.Linear(in_features=124, out_features=n_hidden_neurons),
            nn.BatchNorm1d(num_features=n_hidden_neurons),
            nn.ReLU(),
            nn.Dropout(p=dropout),
        )
        self.mlp = nn.Linear(in_features=n_hidden_neurons, out_features=n_classes)

    def forward(self, x):
        
        embed_x = self.embed_X_block(x)
        logit_class = self.mlp(embed_x)       

        # Compute class-membership probabilities.
        p_class = F.softmax(logit_class, dim=-1)

        return p_class

# %%
from skactiveml.base import SkactivemlClassifier, AnnotatorModelMixin
from skorch import NeuralNet
from skactiveml.utils import is_labeled
from skorch.dataset import unpack_data, Dataset
from skorch.helper import predefined_split

# %%
class SkorchClassifier(NeuralNet, SkactivemlClassifier):
    def __init__(
        self,
        module,
        *args,
        classes=None,
        missing_label=MISSING_LABEL,
        cost_matrix=None,
        random_state=None,
        **module_kwargs,
    ):
        n_classes = len(classes)
        super(SkorchClassifier, self).__init__(
            module,
            *args,
            module__n_classes=n_classes,
            **module_kwargs,
        )
        
        SkactivemlClassifier.__init__(
            self,
            classes=classes,
            missing_label=missing_label,
            cost_matrix=cost_matrix,
            random_state=random_state,
        )
        
        self.regularized = module_kwargs.get("regularized")
        self.lambda1 = module_kwargs.get("lambda1")

    def get_loss(self, y_pred, y_true, *args, **kwargs):
        loss = super(SkorchClassifier, self).get_loss(y_pred, y_true, *args, **kwargs)
        if self.regularized is not None:
            if self.regularized == 1 and self.lambda1 is float:
                loss += self.lambda1 * sum([w.abs().sum() for w in self.module_.parameters()])
        return loss

    def fit(self, X, y, **fit_params):
        # check input parameters
        self.check_X_dict_ = {
            "ensure_min_samples": 0,
            "ensure_min_features": 0,
            "allow_nd": True,
            "dtype": None,
        }
        X, y, sample_weight = self._validate_data(
            X=X,
            y=y,
            check_X_dict=self.check_X_dict_,
        )

        # check whether model is a valid model

        is_lbld = is_labeled(y, missing_label=self.missing_label)
        try:
            X_lbld = X[is_lbld]
            y_lbld = y[is_lbld].astype(np.int64)
            return super(SkorchClassifier, self).fit(X_lbld, y_lbld, **fit_params)
        except Exception as e:
            self.is_fitted_ = False
            return self

    def initialize(self):
        super(SkorchClassifier, self).check_training_readiness()
        
        super(SkorchClassifier, self)._initialize_virtual_params()
        super(SkorchClassifier, self)._initialize_callbacks()
        super(SkorchClassifier, self)._initialize_module()
        super(SkorchClassifier, self)._initialize_criterion()
        super(SkorchClassifier, self)._initialize_optimizer()
        super(SkorchClassifier, self)._initialize_history()
        
        self.initialized_ = True
        return self

    def predict(self, X):
        return SkactivemlClassifier.predict(self, X)

# %%
class CrowdLayerClassifier(SkorchClassifier, AnnotatorModelMixin):
    def __init__(self, *args, **kwargs):
        super(CrowdLayerClassifier, self).__init__(
            module=CrowdLayerModule,
            *args, 
            criterion=CrossEntropyLoss(),
            criterion__reduction="mean",
            criterion__ignore_index=MISSING_LABEL,
            **kwargs,
        )

    def get_loss(self, y_pred, y_true, *args, **kwargs):
        # unpack the tuple from the forward function
        p_class, logits_annot = y_pred
        loss = NeuralNet.get_loss(self, logits_annot, y_true, *args, **kwargs)
        return loss
    
    def fit(self, X, y, **fit_params):
        return NeuralNet.fit(self, X, y, **fit_params)
        
    def predict_annotator_perf(self, X, return_confusion_matrix=False):
        n_annotators = self.module__n_annotators
        P_class, logits_annot = self.forward(X)
        P_class = P_class.numpy()
        P_annot = F.softmax(logits_annot, dim=1)
        P_annot = P_annot.numpy()
        P_perf = np.array([np.einsum("ij,ik->ijk", P_class, P_annot[:, :, i]) for i in range(n_annotators)])
        P_perf = P_perf.swapaxes(0, 1)
        if return_confusion_matrix:
            return P_perf
        return P_perf.diagonal(axis1=-2, axis2=-1).sum(axis=-1)
    
    def predict(self, X):
        p_class, logits_annot = self.forward(X)
        return p_class.argmax(axis=1)
    
    def predict_proba(self, X):
        p_class, logits_annot = self.forward(X)
        P_class = torch.vstack([p for p in p_class]).numpy()
        return P_class
    
    def validation_step(self, batch, **fit_params):
        # here put the all things about validation
        # the following one doesn't work very well
        self._set_training(False)
        Xi, yi = unpack_data(batch)
        with torch.no_grad():
            y_pred = self.predict(Xi)
            acc = torch.sum(y_pred == yi) / y_pred.shape[0]
        return {
            'loss': acc,
            'y_pred': y_pred,
        }
    
class CrowdLayerModule(nn.Module):
    def __init__(
        self,
        n_classes,
        n_annotators,
        gt_net,
    ):
        super().__init__()
        self.n_classes = n_classes
        self.n_annotators = n_annotators
        self.gt_net = gt_net

        # Setup crowd layer.
        self.annotator_layers = nn.ModuleList()
        for i in range(n_annotators):
            layer = nn.Linear(n_classes, n_classes, bias=False)
            layer.weight = nn.Parameter(torch.eye(n_classes) * 10)
            self.annotator_layers.append(layer)

    def forward(self, x):
        """Forward propagation of samples through the GT and AP (optional) model.

        Parameters
        ----------
        x : torch.Tensor of shape (batch_size, *)
            Samples.

        Returns
        -------
        p_class : torch.Tensor of shape (batch_size, n_classes)
            Class-membership probabilities.
        logits_annot : torch.Tensor of shape (batch_size, n_annotators, n_classes)
            Annotation logits for each sample-annotator pair.
        """
        # Compute class-membership logits.
        logit_class = self.gt_net(x)

        # Compute class-membership probabilities.
        p_class = F.softmax(logit_class, dim=-1)

        # Compute logits per annotator.
        logits_annot = []
        for layer in self.annotator_layers:
            logits_annot.append(layer(p_class))
        logits_annot = torch.stack(logits_annot, dim=2)

        return p_class, logits_annot

# %%
gt_net = ClassifierModule(n_classes=n_classes, dropout=0.0)

# %%
valid_ds = Dataset(X_valid, y_valid)

# %%
from skorch.callbacks import LRScheduler

lr_scheduler = LRScheduler(policy="CosineAnnealingLR", T_max=200)

# %%
net = CrowdLayerClassifier(
        module__n_annotators=y_train.shape[1],
        module__gt_net=gt_net,
        classes=dataset_classes,
        missing_label=MISSING_LABEL,
        cost_matrix=None,
        random_state=1,
        train_split=predefined_split(valid_ds),
        max_epochs=200,
        batch_size=64,
        optimizer_lr=0.01,
        verbose=False,
        optimizer=torch.optim.AdamW,
        device=device,
        optimizer__weight_decay=0.001,
        callbacks=[lr_scheduler]
    )

# %%
net.initialize()
# Out:
# <class '__main__.CrowdLayerClassifier'>[initialized](
#   module_=CrowdLayerModule(
#     (gt_net): ClassifierModule(
#       (embed_X_block): Sequential(
#         (0): Linear(in_features=124, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.0, inplace=False)
#       )
#       (mlp): Linear(in_features=128, out_features=10, bias=True)
#     )
#     (annotator_layers): ModuleList(
#       (0-43): 44 x Linear(in_features=10, out_features=10, bias=False)
#     )
#   ),
# )

# %% [markdown]
# ## Active Classification
# For our ensemble, we evaluate four different query strategies, i.e., random sampling, uncertainty sampling, query-by-committee, and batch BALD, regarding their sample selection. For this purpose, we start with ten labels and make 30 iterations of an active learning cycle with a batch size of 32.

# %%
# Define setup.
torch.manual_seed(RANDOM_STATE)
y_train_new = np.column_stack([y_train_true for _ in range(44)])

net.fit(X_train,y_train_new)
# Out:
# <class '__main__.CrowdLayerClassifier'>[initialized](
#   module_=CrowdLayerModule(
#     (gt_net): ClassifierModule(
#       (embed_X_block): Sequential(
#         (0): Linear(in_features=124, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.0, inplace=False)
#       )
#       (mlp): Linear(in_features=128, out_features=10, bias=True)
#     )
#     (annotator_layers): ModuleList(
#       (0-43): 44 x Linear(in_features=10, out_features=10, bias=False)
#     )
#   ),
# )

# %%
net.module_.annotator_layers[0].weight
# Out:
# Parameter containing:
# tensor([[20.2971, -3.9535, -3.5115, -3.6255, -3.2567, -3.2967, -2.4826, -2.7972,
#          -3.1712, -2.8671],
#         [-2.6626, 17.4157, -2.8448, -2.7871, -2.8045, -2.5177, -3.1051, -2.5658,
#          -2.7118, -1.9368],
#         [-2.3438, -3.0643, 17.0297, -1.6768, -2.7768, -2.5408, -2.8383, -2.2675,
#          -2.8279, -1.7045],
#         [-2.6227, -2.9231, -2.5485, 17.0958, -2.5052, -2.7993, -2.9791, -2.2177,
#          -1.6087, -2.1593],
#         [-2.9834, -3.4697, -3.3843, -2.5382, 17.8259, -3.2555, -2.2647, -2.7248,
#          -1.3470, -2.6713],
#         [-2.6030, -1.6972, -2.7852, -3.1816, -3.2290, 18.5831, -3.4955, -2.7954,
#          -2.8180, -2.5348],
#         [-2.5053, -3.1751, -3.2119, -2.8911, -2.7177, -2.9997, 18.3941, -2.4781,
#          -2.9167, -2.1109],
#         [-3.0705, -3.6874, -1.5713, -3.1871, -2.0002, -3.1518, -3.6972, 18.4735,
#          -3.0373, -1.8793],
#         [-2.4278, -3.1665, -2.8916, -2.7381, -0.7977, -2.9998, -3.4826, -1.6105,
#          17.6448, -2.8980],
#         [-2.1857, -3.5951, -1.8659, -1.8661, -1.7552, -2.9770, -2.4441, -2.1405,
#          -2.3006, 17.3727]], requires_grad=True)

# %%
y_pred = net.predict(X_test)
print(y_pred[:20])
print(y_test_true[:20])

print(accuracy_score(y_pred, y_test_true))
# should be 0.675 from MaDL
# Out:
# tensor([1, 9, 2, 6, 1, 7, 4, 1, 1, 7, 3, 2, 4, 2, 3, 4, 2, 2, 3, 3])
# [1 8 2 6 1 7 8 1 1 7 3 2 4 2 3 4 7 5 7 8]
# 0.724

# %%
y_train_pred = net.predict(X_train)
print(y_train_pred[:20])
print(y_train_true[:20])
accuracy_score(y_train_true, y_train_pred)
# Out:
# tensor([4, 7, 4, 7, 8, 3, 2, 2, 8, 3, 0, 6, 7, 2, 2, 0, 5, 2, 8, 8])
# [4 7 4 7 8 3 2 2 8 3 0 6 7 2 2 0 5 2 8 9]
# 0.9371428571428572

# %%
history = net.history
history
# Out:
# [{'batches': [{'train_loss': 2.3076717853546143, 'train_batch_size': 64},
#    {'train_loss': 2.272437572479248, 'train_batch_size': 64},
#    {'train_loss': 2.213801860809326, 'train_batch_size': 64},
#    {'train_loss': 2.1478147506713867, 'train_batch_size': 64},
#    {'train_loss': 2.114445209503174, 'train_batch_size': 64},
#    {'train_loss': 2.115396738052368, 'train_batch_size': 64},
#    {'train_loss': 2.143902063369751, 'train_batch_size': 64},
#    {'train_loss': 2.1856038570404053, 'train_batch_size': 64},
#    {'train_loss': 2.081228017807007, 'train_batch_size': 64},
#    {'train_loss': 2.1091902256011963, 'train_batch_size': 64},
#    {'train_loss': 1.9496123790740967, 'train_batch_size': 60},
#    {'valid_loss': 0.1599999964237213, 'valid_batch_size': 50}],
#   'epoch': 1,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.030659198760986328,
#   'train_loss': 2.150331765583583,
#   'train_loss_best': True,
#   'valid_loss': 0.1599999964237213,
#   'valid_loss_best': True,
#   'event_lr': 0.01},
#  {'batches': [{'train_loss': 2.0223398208618164, 'train_batch_size': 64},
#    {'train_loss': 2.023080587387085, 'train_batch_size': 64},
#    {'train_loss': 1.9767512083053589, 'train_batch_size': 64},
#    {'train_loss': 1.9918148517608643, 'train_batch_size': 64},
#    {'train_loss': 1.8795241117477417, 'train_batch_size': 64},
#    {'train_loss': 1.9774413108825684, 'train_batch_size': 64},
#    {'train_loss': 1.8673241138458252, 'train_batch_size': 64},
#    {'train_loss': 1.9895442724227905, 'train_batch_size': 64},
#    {'train_loss': 1.8914793729782104, 'train_batch_size': 64},
#    {'train_loss': 1.950727939605713, 'train_batch_size': 64},
#    {'train_loss': 1.8705799579620361, 'train_batch_size': 60},
#    {'valid_loss': 0.20000000298023224, 'valid_batch_size': 50}],
#   'epoch': 2,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02898716926574707,
#   'train_loss': 1.949595090321132,
#   'train_loss_best': True,
#   'valid_loss': 0.20000000298023224,
#   'valid_loss_best': False,
#   'event_lr': 0.009999383162408303},
#  {'batches': [{'train_loss': 1.9156543016433716, 'train_batch_size': 64},
#    {'train_loss': 1.961971640586853, 'train_batch_size': 64},
#    {'train_loss': 1.828201413154602, 'train_batch_size': 64},
#    {'train_loss': 1.8633301258087158, 'train_batch_size': 64},
#    {'train_loss': 1.7675591707229614, 'train_batch_size': 64},
#    {'train_loss': 1.8551526069641113, 'train_batch_size': 64},
#    {'train_loss': 1.8034088611602783, 'train_batch_size': 64},
#    {'train_loss': 1.8916183710098267, 'train_batch_size': 64},
#    {'train_loss': 1.7663944959640503, 'train_batch_size': 64},
#    {'train_loss': 1.873843789100647, 'train_batch_size': 64},
#    {'train_loss': 1.774458408355713, 'train_batch_size': 60},
#    {'valid_loss': 0.5600000023841858, 'valid_batch_size': 50}],
#   'epoch': 3,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027673006057739258,
#   'train_loss': 1.8460059002467564,
#   'train_loss_best': True,
#   'valid_loss': 0.5600000023841858,
#   'valid_loss_best': False,
#   'event_lr': 0.009997532801828657},
#  {'batches': [{'train_loss': 1.7859878540039062, 'train_batch_size': 64},
#    {'train_loss': 1.8204281330108643, 'train_batch_size': 64},
#    {'train_loss': 1.687124252319336, 'train_batch_size': 64},
#    {'train_loss': 1.8006420135498047, 'train_batch_size': 64},
#    {'train_loss': 1.7031277418136597, 'train_batch_size': 64},
#    {'train_loss': 1.7189021110534668, 'train_batch_size': 64},
#    {'train_loss': 1.7183994054794312, 'train_batch_size': 64},
#    {'train_loss': 1.7354658842086792, 'train_batch_size': 64},
#    {'train_loss': 1.663806438446045, 'train_batch_size': 64},
#    {'train_loss': 1.7968299388885498, 'train_batch_size': 64},
#    {'train_loss': 1.6482070684432983, 'train_batch_size': 60},
#    {'valid_loss': 0.41999998688697815, 'valid_batch_size': 50}],
#   'epoch': 4,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02755594253540039,
#   'train_loss': 1.7349401508058822,
#   'train_loss_best': True,
#   'valid_loss': 0.41999998688697815,
#   'valid_loss_best': False,
#   'event_lr': 0.00999444937480985},
#  {'batches': [{'train_loss': 1.6785835027694702, 'train_batch_size': 64},
#    {'train_loss': 1.6929256916046143, 'train_batch_size': 64},
#    {'train_loss': 1.6665202379226685, 'train_batch_size': 64},
#    {'train_loss': 1.7417430877685547, 'train_batch_size': 64},
#    {'train_loss': 1.6714988946914673, 'train_batch_size': 64},
#    {'train_loss': 1.6598373651504517, 'train_batch_size': 64},
#    {'train_loss': 1.6451106071472168, 'train_batch_size': 64},
#    {'train_loss': 1.5868706703186035, 'train_batch_size': 64},
#    {'train_loss': 1.6019092798233032, 'train_batch_size': 64},
#    {'train_loss': 1.6964377164840698, 'train_batch_size': 64},
#    {'train_loss': 1.5114305019378662, 'train_batch_size': 60},
#    {'valid_loss': 0.3799999952316284, 'valid_batch_size': 50}],
#   'epoch': 5,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.028128862380981445,
#   'train_loss': 1.651054002216884,
#   'train_loss_best': True,
#   'valid_loss': 0.3799999952316284,
#   'valid_loss_best': False,
#   'event_lr': 0.009990133642141357},
#  {'batches': [{'train_loss': 1.5230530500411987, 'train_batch_size': 64},
#    {'train_loss': 1.6018134355545044, 'train_batch_size': 64},
#    {'train_loss': 1.535786747932434, 'train_batch_size': 64},
#    {'train_loss': 1.6610373258590698, 'train_batch_size': 64},
#    {'train_loss': 1.6323398351669312, 'train_batch_size': 64},
#    {'train_loss': 1.5317410230636597, 'train_batch_size': 64},
#    {'train_loss': 1.623219609260559, 'train_batch_size': 64},
#    {'train_loss': 1.5063488483428955, 'train_batch_size': 64},
#    {'train_loss': 1.5250308513641357, 'train_batch_size': 64},
#    {'train_loss': 1.634896159172058, 'train_batch_size': 64},
#    {'train_loss': 1.432727336883545, 'train_batch_size': 60},
#    {'valid_loss': 0.3400000035762787, 'valid_batch_size': 50}],
#   'epoch': 6,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027788162231445312,
#   'train_loss': 1.565115315573556,
#   'train_loss_best': True,
#   'valid_loss': 0.3400000035762787,
#   'valid_loss_best': False,
#   'event_lr': 0.009984586668665639},
#  {'batches': [{'train_loss': 1.5121986865997314, 'train_batch_size': 64},
#    {'train_loss': 1.5634033679962158, 'train_batch_size': 64},
#    {'train_loss': 1.479698657989502, 'train_batch_size': 64},
#    {'train_loss': 1.6140633821487427, 'train_batch_size': 64},
#    {'train_loss': 1.5635899305343628, 'train_batch_size': 64},
#    {'train_loss': 1.443676233291626, 'train_batch_size': 64},
#    {'train_loss': 1.5182311534881592, 'train_batch_size': 64},
#    {'train_loss': 1.4466485977172852, 'train_batch_size': 64},
#    {'train_loss': 1.4818660020828247, 'train_batch_size': 64},
#    {'train_loss': 1.5945876836776733, 'train_batch_size': 64},
#    {'train_loss': 1.351489782333374, 'train_batch_size': 60},
#    {'valid_loss': 0.6399999856948853, 'valid_batch_size': 50}],
#   'epoch': 7,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02726292610168457,
#   'train_loss': 1.5071986620766775,
#   'train_loss_best': True,
#   'valid_loss': 0.6399999856948853,
#   'valid_loss_best': False,
#   'event_lr': 0.009977809823015398},
#  {'batches': [{'train_loss': 1.4648289680480957, 'train_batch_size': 64},
#    {'train_loss': 1.4946091175079346, 'train_batch_size': 64},
#    {'train_loss': 1.4664620161056519, 'train_batch_size': 64},
#    {'train_loss': 1.5787429809570312, 'train_batch_size': 64},
#    {'train_loss': 1.529297947883606, 'train_batch_size': 64},
#    {'train_loss': 1.382151484489441, 'train_batch_size': 64},
#    {'train_loss': 1.4401984214782715, 'train_batch_size': 64},
#    {'train_loss': 1.449216365814209, 'train_batch_size': 64},
#    {'train_loss': 1.4040757417678833, 'train_batch_size': 64},
#    {'train_loss': 1.533974528312683, 'train_batch_size': 64},
#    {'train_loss': 1.347512125968933, 'train_batch_size': 60},
#    {'valid_loss': 0.6600000262260437, 'valid_batch_size': 50}],
#   'epoch': 8,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027356863021850586,
#   'train_loss': 1.4634834459849766,
#   'train_loss_best': True,
#   'valid_loss': 0.6600000262260437,
#   'valid_loss_best': False,
#   'event_lr': 0.009969804777275897},
#  {'batches': [{'train_loss': 1.427198886871338, 'train_batch_size': 64},
#    {'train_loss': 1.436146855354309, 'train_batch_size': 64},
#    {'train_loss': 1.3973603248596191, 'train_batch_size': 64},
#    {'train_loss': 1.5451653003692627, 'train_batch_size': 64},
#    {'train_loss': 1.4538073539733887, 'train_batch_size': 64},
#    {'train_loss': 1.3490328788757324, 'train_batch_size': 64},
#    {'train_loss': 1.3750622272491455, 'train_batch_size': 64},
#    {'train_loss': 1.4302810430526733, 'train_batch_size': 64},
#    {'train_loss': 1.360277533531189, 'train_batch_size': 64},
#    {'train_loss': 1.4994205236434937, 'train_batch_size': 64},
#    {'train_loss': 1.3438464403152466, 'train_batch_size': 60},
#    {'valid_loss': 0.6399999856948853, 'valid_batch_size': 50}],
#   'epoch': 9,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.08509707450866699,
#   'train_loss': 1.420215676852635,
#   'train_loss_best': True,
#   'valid_loss': 0.6399999856948853,
#   'valid_loss_best': False,
#   'event_lr': 0.009960573506572387},
#  {'batches': [{'train_loss': 1.3757869005203247, 'train_batch_size': 64},
#    {'train_loss': 1.4095555543899536, 'train_batch_size': 64},
#    {'train_loss': 1.4351675510406494, 'train_batch_size': 64},
#    {'train_loss': 1.5516715049743652, 'train_batch_size': 64},
#    {'train_loss': 1.4242419004440308, 'train_batch_size': 64},
#    {'train_loss': 1.3262096643447876, 'train_batch_size': 64},
#    {'train_loss': 1.3349336385726929, 'train_batch_size': 64},
#    {'train_loss': 1.3801010847091675, 'train_batch_size': 64},
#    {'train_loss': 1.3099209070205688, 'train_batch_size': 64},
#    {'train_loss': 1.4385353326797485, 'train_batch_size': 64},
#    {'train_loss': 1.259887933731079, 'train_batch_size': 60},
#    {'valid_loss': 0.46000000834465027, 'valid_batch_size': 50}],
#   'epoch': 10,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.12238001823425293,
#   'train_loss': 1.3867217350006102,
#   'train_loss_best': True,
#   'valid_loss': 0.46000000834465027,
#   'valid_loss_best': False,
#   'event_lr': 0.009950118288582784},
#  {'batches': [{'train_loss': 1.339994192123413, 'train_batch_size': 64},
#    {'train_loss': 1.3558963537216187, 'train_batch_size': 64},
#    {'train_loss': 1.3619266748428345, 'train_batch_size': 64},
#    {'train_loss': 1.5281792879104614, 'train_batch_size': 64},
#    {'train_loss': 1.4505535364151, 'train_batch_size': 64},
#    {'train_loss': 1.242011547088623, 'train_batch_size': 64},
#    {'train_loss': 1.3103941679000854, 'train_batch_size': 64},
#    {'train_loss': 1.3502305746078491, 'train_batch_size': 64},
#    {'train_loss': 1.2789363861083984, 'train_batch_size': 64},
#    {'train_loss': 1.4262804985046387, 'train_batch_size': 64},
#    {'train_loss': 1.233338475227356, 'train_batch_size': 60},
#    {'valid_loss': 0.6800000071525574, 'valid_batch_size': 50}],
#   'epoch': 11,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.04025602340698242,
#   'train_loss': 1.3532030207770211,
#   'train_loss_best': True,
#   'valid_loss': 0.6800000071525574,
#   'valid_loss_best': False,
#   'event_lr': 0.009938441702975684},
#  {'batches': [{'train_loss': 1.3064544200897217, 'train_batch_size': 64},
#    {'train_loss': 1.340799331665039, 'train_batch_size': 64},
#    {'train_loss': 1.3661558628082275, 'train_batch_size': 64},
#    {'train_loss': 1.4651832580566406, 'train_batch_size': 64},
#    {'train_loss': 1.383982539176941, 'train_batch_size': 64},
#    {'train_loss': 1.2487568855285645, 'train_batch_size': 64},
#    {'train_loss': 1.2889400720596313, 'train_batch_size': 64},
#    {'train_loss': 1.343536376953125, 'train_batch_size': 64},
#    {'train_loss': 1.2622374296188354, 'train_batch_size': 64},
#    {'train_loss': 1.3817654848098755, 'train_batch_size': 64},
#    {'train_loss': 1.2091312408447266, 'train_batch_size': 60},
#    {'valid_loss': 0.4399999976158142, 'valid_batch_size': 50}],
#   'epoch': 12,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.06870484352111816,
#   'train_loss': 1.3276683153424944,
#   'train_loss_best': True,
#   'valid_loss': 0.4399999976158142,
#   'valid_loss_best': False,
#   'event_lr': 0.009925546630773864},
#  {'batches': [{'train_loss': 1.2909194231033325, 'train_batch_size': 64},
#    {'train_loss': 1.2889597415924072, 'train_batch_size': 64},
#    {'train_loss': 1.2945812940597534, 'train_batch_size': 64},
#    {'train_loss': 1.456578016281128, 'train_batch_size': 64},
#    {'train_loss': 1.3816184997558594, 'train_batch_size': 64},
#    {'train_loss': 1.256477952003479, 'train_batch_size': 64},
#    {'train_loss': 1.2678605318069458, 'train_batch_size': 64},
#    {'train_loss': 1.2907984256744385, 'train_batch_size': 64},
#    {'train_loss': 1.243228793144226, 'train_batch_size': 64},
#    {'train_loss': 1.3717106580734253, 'train_batch_size': 64},
#    {'train_loss': 1.1950169801712036, 'train_batch_size': 60},
#    {'valid_loss': 0.6399999856948853, 'valid_batch_size': 50}],
#   'epoch': 13,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.04315805435180664,
#   'train_loss': 1.3040513604027884,
#   'train_loss_best': True,
#   'valid_loss': 0.6399999856948853,
#   'valid_loss_best': False,
#   'event_lr': 0.009911436253643439},
#  {'batches': [{'train_loss': 1.2453862428665161, 'train_batch_size': 64},
#    {'train_loss': 1.246910810470581, 'train_batch_size': 64},
#    {'train_loss': 1.297791600227356, 'train_batch_size': 64},
#    {'train_loss': 1.4331459999084473, 'train_batch_size': 64},
#    {'train_loss': 1.350122094154358, 'train_batch_size': 64},
#    {'train_loss': 1.1977286338806152, 'train_batch_size': 64},
#    {'train_loss': 1.2646511793136597, 'train_batch_size': 64},
#    {'train_loss': 1.3220781087875366, 'train_batch_size': 64},
#    {'train_loss': 1.2250982522964478, 'train_batch_size': 64},
#    {'train_loss': 1.3027191162109375, 'train_batch_size': 64},
#    {'train_loss': 1.1691594123840332, 'train_batch_size': 60},
#    {'valid_loss': 0.4399999976158142, 'valid_batch_size': 50}],
#   'epoch': 14,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.039930105209350586,
#   'train_loss': 1.27832859311785,
#   'train_loss_best': True,
#   'valid_loss': 0.4399999976158142,
#   'valid_loss_best': False,
#   'event_lr': 0.009896114053108824},
#  {'batches': [{'train_loss': 1.243268609046936, 'train_batch_size': 64},
#    {'train_loss': 1.2486605644226074, 'train_batch_size': 64},
#    {'train_loss': 1.2928158044815063, 'train_batch_size': 64},
#    {'train_loss': 1.3794211149215698, 'train_batch_size': 64},
#    {'train_loss': 1.3635634183883667, 'train_batch_size': 64},
#    {'train_loss': 1.1208205223083496, 'train_batch_size': 64},
#    {'train_loss': 1.2082493305206299, 'train_batch_size': 64},
#    {'train_loss': 1.2646244764328003, 'train_batch_size': 64},
#    {'train_loss': 1.2347471714019775, 'train_batch_size': 64},
#    {'train_loss': 1.2696398496627808, 'train_batch_size': 64},
#    {'train_loss': 1.1371219158172607, 'train_batch_size': 60},
#    {'valid_loss': 0.5199999809265137, 'valid_batch_size': 50}],
#   'epoch': 15,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.03294706344604492,
#   'train_loss': 1.2518274429866245,
#   'train_loss_best': True,
#   'valid_loss': 0.5199999809265137,
#   'valid_loss_best': False,
#   'event_lr': 0.009879583809693733},
#  {'batches': [{'train_loss': 1.2283037900924683, 'train_batch_size': 64},
#    {'train_loss': 1.199489951133728, 'train_batch_size': 64},
#    {'train_loss': 1.2161258459091187, 'train_batch_size': 64},
#    {'train_loss': 1.3754626512527466, 'train_batch_size': 64},
#    {'train_loss': 1.3333649635314941, 'train_batch_size': 64},
#    {'train_loss': 1.1213170289993286, 'train_batch_size': 64},
#    {'train_loss': 1.1940973997116089, 'train_batch_size': 64},
#    {'train_loss': 1.2535223960876465, 'train_batch_size': 64},
#    {'train_loss': 1.164381980895996, 'train_batch_size': 64},
#    {'train_loss': 1.2287744283676147, 'train_batch_size': 64},
#    {'train_loss': 1.1247384548187256, 'train_batch_size': 60},
#    {'valid_loss': 0.5199999809265137, 'valid_batch_size': 50}],
#   'epoch': 16,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027527809143066406,
#   'train_loss': 1.2223344217027936,
#   'train_loss_best': True,
#   'valid_loss': 0.5199999809265137,
#   'valid_loss_best': False,
#   'event_lr': 0.009861849601988378},
#  {'batches': [{'train_loss': 1.1881883144378662, 'train_batch_size': 64},
#    {'train_loss': 1.2199667692184448, 'train_batch_size': 64},
#    {'train_loss': 1.269731044769287, 'train_batch_size': 64},
#    {'train_loss': 1.4093432426452637, 'train_batch_size': 64},
#    {'train_loss': 1.3598328828811646, 'train_batch_size': 64},
#    {'train_loss': 1.1155356168746948, 'train_batch_size': 64},
#    {'train_loss': 1.1787563562393188, 'train_batch_size': 64},
#    {'train_loss': 1.2672611474990845, 'train_batch_size': 64},
#    {'train_loss': 1.1623984575271606, 'train_batch_size': 64},
#    {'train_loss': 1.2014473676681519, 'train_batch_size': 64},
#    {'train_loss': 1.1308706998825073, 'train_batch_size': 60},
#    {'valid_loss': 0.5799999833106995, 'valid_batch_size': 50}],
#   'epoch': 17,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027745723724365234,
#   'train_loss': 1.2281282268251692,
#   'train_loss_best': False,
#   'valid_loss': 0.5799999833106995,
#   'valid_loss_best': False,
#   'event_lr': 0.00984291580564315},
#  {'batches': [{'train_loss': 1.1971560716629028, 'train_batch_size': 64},
#    {'train_loss': 1.1749577522277832, 'train_batch_size': 64},
#    {'train_loss': 1.1907325983047485, 'train_batch_size': 64},
#    {'train_loss': 1.3065226078033447, 'train_batch_size': 64},
#    {'train_loss': 1.3057197332382202, 'train_batch_size': 64},
#    {'train_loss': 1.1209381818771362, 'train_batch_size': 64},
#    {'train_loss': 1.2200355529785156, 'train_batch_size': 64},
#    {'train_loss': 1.2123379707336426, 'train_batch_size': 64},
#    {'train_loss': 1.1400024890899658, 'train_batch_size': 64},
#    {'train_loss': 1.2510831356048584, 'train_batch_size': 64},
#    {'train_loss': 1.135040521621704, 'train_batch_size': 60},
#    {'valid_loss': 0.3799999952316284, 'valid_batch_size': 50}],
#   'epoch': 18,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02770400047302246,
#   'train_loss': 1.2053564875466483,
#   'train_loss_best': True,
#   'valid_loss': 0.3799999952316284,
#   'valid_loss_best': False,
#   'event_lr': 0.009822787092288985},
#  {'batches': [{'train_loss': 1.180789589881897, 'train_batch_size': 64},
#    {'train_loss': 1.2134301662445068, 'train_batch_size': 64},
#    {'train_loss': 1.1605991125106812, 'train_batch_size': 64},
#    {'train_loss': 1.3130279779434204, 'train_batch_size': 64},
#    {'train_loss': 1.3024414777755737, 'train_batch_size': 64},
#    {'train_loss': 1.093799114227295, 'train_batch_size': 64},
#    {'train_loss': 1.1712217330932617, 'train_batch_size': 64},
#    {'train_loss': 1.2140755653381348, 'train_batch_size': 64},
#    {'train_loss': 1.1394108533859253, 'train_batch_size': 64},
#    {'train_loss': 1.1807783842086792, 'train_batch_size': 64},
#    {'train_loss': 1.0861401557922363, 'train_batch_size': 60},
#    {'valid_loss': 0.6000000238418579, 'valid_batch_size': 50}],
#   'epoch': 19,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027281761169433594,
#   'train_loss': 1.1874587767464775,
#   'train_loss_best': True,
#   'valid_loss': 0.6000000238418579,
#   'valid_loss_best': False,
#   'event_lr': 0.00980146842838471},
#  {'batches': [{'train_loss': 1.1819130182266235, 'train_batch_size': 64},
#    {'train_loss': 1.2169438600540161, 'train_batch_size': 64},
#    {'train_loss': 1.15427565574646, 'train_batch_size': 64},
#    {'train_loss': 1.359499454498291, 'train_batch_size': 64},
#    {'train_loss': 1.2696541547775269, 'train_batch_size': 64},
#    {'train_loss': 1.120147943496704, 'train_batch_size': 64},
#    {'train_loss': 1.1424405574798584, 'train_batch_size': 64},
#    {'train_loss': 1.1955288648605347, 'train_batch_size': 64},
#    {'train_loss': 1.1194247007369995, 'train_batch_size': 64},
#    {'train_loss': 1.1909812688827515, 'train_batch_size': 64},
#    {'train_loss': 1.0715450048446655, 'train_batch_size': 60},
#    {'valid_loss': 0.6800000071525574, 'valid_batch_size': 50}],
#   'epoch': 20,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.0311129093170166,
#   'train_loss': 1.184492152759007,
#   'train_loss_best': True,
#   'valid_loss': 0.6800000071525574,
#   'valid_loss_best': False,
#   'event_lr': 0.009778965073991645},
#  {'batches': [{'train_loss': 1.1664438247680664, 'train_batch_size': 64},
#    {'train_loss': 1.1439648866653442, 'train_batch_size': 64},
#    {'train_loss': 1.1653646230697632, 'train_batch_size': 64},
#    {'train_loss': 1.2323683500289917, 'train_batch_size': 64},
#    {'train_loss': 1.2653688192367554, 'train_batch_size': 64},
#    {'train_loss': 1.036558985710144, 'train_batch_size': 64},
#    {'train_loss': 1.1158634424209595, 'train_batch_size': 64},
#    {'train_loss': 1.1628419160842896, 'train_batch_size': 64},
#    {'train_loss': 1.093273639678955, 'train_batch_size': 64},
#    {'train_loss': 1.1728142499923706, 'train_batch_size': 64},
#    {'train_loss': 1.0583487749099731, 'train_batch_size': 60},
#    {'valid_loss': 0.5400000214576721, 'valid_batch_size': 50}],
#   'epoch': 21,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.07670974731445312,
#   'train_loss': 1.1471602024350847,
#   'train_loss_best': True,
#   'valid_loss': 0.5400000214576721,
#   'valid_loss_best': False,
#   'event_lr': 0.009755282581475762},
#  {'batches': [{'train_loss': 1.1536993980407715, 'train_batch_size': 64},
#    {'train_loss': 1.1717835664749146, 'train_batch_size': 64},
#    {'train_loss': 1.1129860877990723, 'train_batch_size': 64},
#    {'train_loss': 1.2869921922683716, 'train_batch_size': 64},
#    {'train_loss': 1.2535916566848755, 'train_batch_size': 64},
#    {'train_loss': 1.0142385959625244, 'train_batch_size': 64},
#    {'train_loss': 1.1150189638137817, 'train_batch_size': 64},
#    {'train_loss': 1.1660544872283936, 'train_batch_size': 64},
#    {'train_loss': 1.0927236080169678, 'train_batch_size': 64},
#    {'train_loss': 1.1461225748062134, 'train_batch_size': 64},
#    {'train_loss': 1.052973747253418, 'train_batch_size': 60},
#    {'valid_loss': 0.699999988079071, 'valid_batch_size': 50}],
#   'epoch': 22,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.08531928062438965,
#   'train_loss': 1.1428913388933455,
#   'train_loss_best': True,
#   'valid_loss': 0.699999988079071,
#   'valid_loss_best': False,
#   'event_lr': 0.00973042679413772},
#  {'batches': [{'train_loss': 1.1424288749694824, 'train_batch_size': 64},
#    {'train_loss': 1.1271679401397705, 'train_batch_size': 64},
#    {'train_loss': 1.0850883722305298, 'train_batch_size': 64},
#    {'train_loss': 1.2343674898147583, 'train_batch_size': 64},
#    {'train_loss': 1.2557761669158936, 'train_batch_size': 64},
#    {'train_loss': 0.9981359243392944, 'train_batch_size': 64},
#    {'train_loss': 1.1090178489685059, 'train_batch_size': 64},
#    {'train_loss': 1.1127463579177856, 'train_batch_size': 64},
#    {'train_loss': 1.0877020359039307, 'train_batch_size': 64},
#    {'train_loss': 1.0888800621032715, 'train_batch_size': 64},
#    {'train_loss': 1.0473706722259521, 'train_batch_size': 60},
#    {'valid_loss': 0.5799999833106995, 'valid_batch_size': 50}],
#   'epoch': 23,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.12378692626953125,
#   'train_loss': 1.1175516414642335,
#   'train_loss_best': True,
#   'valid_loss': 0.5799999833106995,
#   'valid_loss_best': False,
#   'event_lr': 0.00970440384477112},
#  {'batches': [{'train_loss': 1.134938359260559, 'train_batch_size': 64},
#    {'train_loss': 1.1326872110366821, 'train_batch_size': 64},
#    {'train_loss': 1.0646439790725708, 'train_batch_size': 64},
#    {'train_loss': 1.1953330039978027, 'train_batch_size': 64},
#    {'train_loss': 1.2387003898620605, 'train_batch_size': 64},
#    {'train_loss': 0.9852065443992615, 'train_batch_size': 64},
#    {'train_loss': 1.0752259492874146, 'train_batch_size': 64},
#    {'train_loss': 1.09989595413208, 'train_batch_size': 64},
#    {'train_loss': 1.0663880109786987, 'train_batch_size': 64},
#    {'train_loss': 1.0381802320480347, 'train_batch_size': 64},
#    {'train_loss': 1.029533863067627, 'train_batch_size': 60},
#    {'valid_loss': 0.7400000095367432, 'valid_batch_size': 50}],
#   'epoch': 24,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.0478978157043457,
#   'train_loss': 1.096812583378383,
#   'train_loss_best': True,
#   'valid_loss': 0.7400000095367432,
#   'valid_loss_best': False,
#   'event_lr': 0.00967722015414933},
#  {'batches': [{'train_loss': 1.1258372068405151, 'train_batch_size': 64},
#    {'train_loss': 1.1081043481826782, 'train_batch_size': 64},
#    {'train_loss': 1.0597845315933228, 'train_batch_size': 64},
#    {'train_loss': 1.2125102281570435, 'train_batch_size': 64},
#    {'train_loss': 1.226974368095398, 'train_batch_size': 64},
#    {'train_loss': 1.004439353942871, 'train_batch_size': 64},
#    {'train_loss': 1.078382968902588, 'train_batch_size': 64},
#    {'train_loss': 1.0587493181228638, 'train_batch_size': 64},
#    {'train_loss': 1.0399919748306274, 'train_batch_size': 64},
#    {'train_loss': 1.0288203954696655, 'train_batch_size': 64},
#    {'train_loss': 1.0175716876983643, 'train_batch_size': 60},
#    {'valid_loss': 0.699999988079071, 'valid_batch_size': 50}],
#   'epoch': 25,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.0313568115234375,
#   'train_loss': 1.087777659552438,
#   'train_loss_best': True,
#   'valid_loss': 0.699999988079071,
#   'valid_loss_best': False,
#   'event_lr': 0.00964888242944125},
#  {'batches': [{'train_loss': 1.1106836795806885, 'train_batch_size': 64},
#    {'train_loss': 1.090267539024353, 'train_batch_size': 64},
#    {'train_loss': 1.024491310119629, 'train_batch_size': 64},
#    {'train_loss': 1.1971148252487183, 'train_batch_size': 64},
#    {'train_loss': 1.1925076246261597, 'train_batch_size': 64},
#    {'train_loss': 0.973776638507843, 'train_batch_size': 64},
#    {'train_loss': 1.0512783527374268, 'train_batch_size': 64},
#    {'train_loss': 1.0460296869277954, 'train_batch_size': 64},
#    {'train_loss': 1.0303512811660767, 'train_batch_size': 64},
#    {'train_loss': 1.0187938213348389, 'train_batch_size': 64},
#    {'train_loss': 1.005435824394226, 'train_batch_size': 60},
#    {'valid_loss': 0.6800000071525574, 'valid_batch_size': 50}],
#   'epoch': 26,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.030644893646240234,
#   'train_loss': 1.0676928772245136,
#   'train_loss_best': True,
#   'valid_loss': 0.6800000071525574,
#   'valid_loss_best': False,
#   'event_lr': 0.009619397662556426},
#  {'batches': [{'train_loss': 1.0954371690750122, 'train_batch_size': 64},
#    {'train_loss': 1.0842801332473755, 'train_batch_size': 64},
#    {'train_loss': 1.008320689201355, 'train_batch_size': 64},
#    {'train_loss': 1.1881153583526611, 'train_batch_size': 64},
#    {'train_loss': 1.1777008771896362, 'train_batch_size': 64},
#    {'train_loss': 0.9562629461288452, 'train_batch_size': 64},
#    {'train_loss': 1.0335274934768677, 'train_batch_size': 64},
#    {'train_loss': 1.0484012365341187, 'train_batch_size': 64},
#    {'train_loss': 1.017092227935791, 'train_batch_size': 64},
#    {'train_loss': 0.9657663702964783, 'train_batch_size': 64},
#    {'train_loss': 1.0036075115203857, 'train_batch_size': 60},
#    {'valid_loss': 0.7200000286102295, 'valid_batch_size': 50}],
#   'epoch': 27,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02871108055114746,
#   'train_loss': 1.0528719125475203,
#   'train_loss_best': True,
#   'valid_loss': 0.7200000286102295,
#   'valid_loss_best': False,
#   'event_lr': 0.009588773128419898},
#  {'batches': [{'train_loss': 1.0577406883239746, 'train_batch_size': 64},
#    {'train_loss': 1.0708562135696411, 'train_batch_size': 64},
#    {'train_loss': 0.9955559372901917, 'train_batch_size': 64},
#    {'train_loss': 1.1777453422546387, 'train_batch_size': 64},
#    {'train_loss': 1.188602328300476, 'train_batch_size': 64},
#    {'train_loss': 0.9773854613304138, 'train_batch_size': 64},
#    {'train_loss': 1.0588146448135376, 'train_batch_size': 64},
#    {'train_loss': 1.0269670486450195, 'train_batch_size': 64},
#    {'train_loss': 1.01121187210083, 'train_batch_size': 64},
#    {'train_loss': 0.9724978804588318, 'train_batch_size': 64},
#    {'train_loss': 1.0010501146316528, 'train_batch_size': 60},
#    {'valid_loss': 0.5799999833106995, 'valid_batch_size': 50}],
#   'epoch': 28,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.0277712345123291,
#   'train_loss': 1.049221659387861,
#   'train_loss_best': True,
#   'valid_loss': 0.5799999833106995,
#   'valid_loss_best': False,
#   'event_lr': 0.009557016383177219},
#  {'batches': [{'train_loss': 1.0516948699951172, 'train_batch_size': 64},
#    {'train_loss': 1.0647145509719849, 'train_batch_size': 64},
#    {'train_loss': 1.0266108512878418, 'train_batch_size': 64},
#    {'train_loss': 1.1644577980041504, 'train_batch_size': 64},
#    {'train_loss': 1.1493512392044067, 'train_batch_size': 64},
#    {'train_loss': 0.9451212286949158, 'train_batch_size': 64},
#    {'train_loss': 1.0304855108261108, 'train_batch_size': 64},
#    {'train_loss': 1.0322356224060059, 'train_batch_size': 64},
#    {'train_loss': 1.0033332109451294, 'train_batch_size': 64},
#    {'train_loss': 0.9819166660308838, 'train_batch_size': 64},
#    {'train_loss': 0.9805231094360352, 'train_batch_size': 60},
#    {'valid_loss': 0.47999998927116394, 'valid_batch_size': 50}],
#   'epoch': 29,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02884197235107422,
#   'train_loss': 1.0394662366594587,
#   'train_loss_best': True,
#   'valid_loss': 0.47999998927116394,
#   'valid_loss_best': False,
#   'event_lr': 0.009524135262330091},
#  {'batches': [{'train_loss': 1.046937108039856, 'train_batch_size': 64},
#    {'train_loss': 1.0587445497512817, 'train_batch_size': 64},
#    {'train_loss': 0.9893764853477478, 'train_batch_size': 64},
#    {'train_loss': 1.138181209564209, 'train_batch_size': 64},
#    {'train_loss': 1.139737844467163, 'train_batch_size': 64},
#    {'train_loss': 0.9337978363037109, 'train_batch_size': 64},
#    {'train_loss': 1.0312329530715942, 'train_batch_size': 64},
#    {'train_loss': 1.0061185359954834, 'train_batch_size': 64},
#    {'train_loss': 0.9915614724159241, 'train_batch_size': 64},
#    {'train_loss': 0.9047040939331055, 'train_batch_size': 64},
#    {'train_loss': 0.979604184627533, 'train_batch_size': 60},
#    {'valid_loss': 0.7200000286102295, 'valid_batch_size': 50}],
#   'epoch': 30,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02828812599182129,
#   'train_loss': 1.0202304925237382,
#   'train_loss_best': True,
#   'valid_loss': 0.7200000286102295,
#   'valid_loss_best': False,
#   'event_lr': 0.009490137878803071},
#  {'batches': [{'train_loss': 1.0812087059020996, 'train_batch_size': 64},
#    {'train_loss': 1.0551997423171997, 'train_batch_size': 64},
#    {'train_loss': 0.9945383667945862, 'train_batch_size': 64},
#    {'train_loss': 1.1078673601150513, 'train_batch_size': 64},
#    {'train_loss': 1.137285828590393, 'train_batch_size': 64},
#    {'train_loss': 0.9191446900367737, 'train_batch_size': 64},
#    {'train_loss': 0.9892480373382568, 'train_batch_size': 64},
#    {'train_loss': 1.03142511844635, 'train_batch_size': 64},
#    {'train_loss': 0.9635087847709656, 'train_batch_size': 64},
#    {'train_loss': 0.9257053136825562, 'train_batch_size': 64},
#    {'train_loss': 0.9787126183509827, 'train_batch_size': 60},
#    {'valid_loss': 0.6000000238418579, 'valid_batch_size': 50}],
#   'epoch': 31,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02756500244140625,
#   'train_loss': 1.0169302882466997,
#   'train_loss_best': True,
#   'valid_loss': 0.6000000238418579,
#   'valid_loss_best': False,
#   'event_lr': 0.009455032620941833},
#  {'batches': [{'train_loss': 1.0724714994430542, 'train_batch_size': 64},
#    {'train_loss': 1.082245945930481, 'train_batch_size': 64},
#    {'train_loss': 1.0055359601974487, 'train_batch_size': 64},
#    {'train_loss': 1.1091862916946411, 'train_batch_size': 64},
#    {'train_loss': 1.1150047779083252, 'train_batch_size': 64},
#    {'train_loss': 0.9124413132667542, 'train_batch_size': 64},
#    {'train_loss': 0.9734359383583069, 'train_batch_size': 64},
#    {'train_loss': 0.9979440569877625, 'train_batch_size': 64},
#    {'train_loss': 0.9639700055122375, 'train_batch_size': 64},
#    {'train_loss': 0.9057268500328064, 'train_batch_size': 64},
#    {'train_loss': 0.9601297974586487, 'train_batch_size': 60},
#    {'valid_loss': 0.5799999833106995, 'valid_batch_size': 50}],
#   'epoch': 32,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02756810188293457,
#   'train_loss': 1.0091962810925075,
#   'train_loss_best': True,
#   'valid_loss': 0.5799999833106995,
#   'valid_loss_best': False,
#   'event_lr': 0.009418828150443462},
#  {'batches': [{'train_loss': 1.0388340950012207, 'train_batch_size': 64},
#    {'train_loss': 1.0365180969238281, 'train_batch_size': 64},
#    {'train_loss': 0.97784823179245, 'train_batch_size': 64},
#    {'train_loss': 1.0773483514785767, 'train_batch_size': 64},
#    {'train_loss': 1.1053462028503418, 'train_batch_size': 64},
#    {'train_loss': 0.902737021446228, 'train_batch_size': 64},
#    {'train_loss': 0.9734160900115967, 'train_batch_size': 64},
#    {'train_loss': 0.9694582223892212, 'train_batch_size': 64},
#    {'train_loss': 0.9454594254493713, 'train_batch_size': 64},
#    {'train_loss': 0.9379905462265015, 'train_batch_size': 64},
#    {'train_loss': 0.9406359195709229, 'train_batch_size': 60},
#    {'valid_loss': 0.6800000071525574, 'valid_batch_size': 50}],
#   'epoch': 33,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02769613265991211,
#   'train_loss': 0.9917076533181327,
#   'train_loss_best': True,
#   'valid_loss': 0.6800000071525574,
#   'valid_loss_best': False,
#   'event_lr': 0.009381533400219312},
#  {'batches': [{'train_loss': 1.0012701749801636, 'train_batch_size': 64},
#    {'train_loss': 1.0221624374389648, 'train_batch_size': 64},
#    {'train_loss': 0.9613445401191711, 'train_batch_size': 64},
#    {'train_loss': 1.048919677734375, 'train_batch_size': 64},
#    {'train_loss': 1.0764561891555786, 'train_batch_size': 64},
#    {'train_loss': 0.8954059481620789, 'train_batch_size': 64},
#    {'train_loss': 0.9532716870307922, 'train_batch_size': 64},
#    {'train_loss': 0.9495964050292969, 'train_batch_size': 64},
#    {'train_loss': 0.9486642479896545, 'train_batch_size': 64},
#    {'train_loss': 0.8994501233100891, 'train_batch_size': 64},
#    {'train_loss': 0.9386082291603088, 'train_batch_size': 60},
#    {'valid_loss': 0.6000000238418579, 'valid_batch_size': 50}],
#   'epoch': 34,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027572154998779297,
#   'train_loss': 0.9724787790434701,
#   'train_loss_best': True,
#   'valid_loss': 0.6000000238418579,
#   'valid_loss_best': False,
#   'event_lr': 0.00934315757219095},
#  {'batches': [{'train_loss': 0.9970319867134094, 'train_batch_size': 64},
#    {'train_loss': 1.0112500190734863, 'train_batch_size': 64},
#    {'train_loss': 0.9616987705230713, 'train_batch_size': 64},
#    {'train_loss': 1.1161999702453613, 'train_batch_size': 64},
#    {'train_loss': 1.143362045288086, 'train_batch_size': 64},
#    {'train_loss': 0.9375184774398804, 'train_batch_size': 64},
#    {'train_loss': 0.9861703515052795, 'train_batch_size': 64},
#    {'train_loss': 1.006089687347412, 'train_batch_size': 64},
#    {'train_loss': 0.9916067719459534, 'train_batch_size': 64},
#    {'train_loss': 0.9402289986610413, 'train_batch_size': 64},
#    {'train_loss': 0.9325993657112122, 'train_batch_size': 60},
#    {'valid_loss': 0.6399999856948853, 'valid_batch_size': 50}],
#   'epoch': 35,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027514219284057617,
#   'train_loss': 1.0025571642603193,
#   'train_loss_best': False,
#   'valid_loss': 0.6399999856948853,
#   'valid_loss_best': False,
#   'event_lr': 0.009303710135019712},
#  {'batches': [{'train_loss': 1.071362018585205, 'train_batch_size': 64},
#    {'train_loss': 1.0246946811676025, 'train_batch_size': 64},
#    {'train_loss': 0.9751741886138916, 'train_batch_size': 64},
#    {'train_loss': 1.0519126653671265, 'train_batch_size': 64},
#    {'train_loss': 1.1293772459030151, 'train_batch_size': 64},
#    {'train_loss': 0.9895665645599365, 'train_batch_size': 64},
#    {'train_loss': 0.9608566164970398, 'train_batch_size': 64},
#    {'train_loss': 0.9725242853164673, 'train_batch_size': 64},
#    {'train_loss': 0.9733706116676331, 'train_batch_size': 64},
#    {'train_loss': 0.9091643691062927, 'train_batch_size': 64},
#    {'train_loss': 0.9200233221054077, 'train_batch_size': 60},
#    {'valid_loss': 0.5799999833106995, 'valid_batch_size': 50}],
#   'epoch': 36,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027446985244750977,
#   'train_loss': 0.9984480101721628,
#   'train_loss_best': False,
#   'valid_loss': 0.5799999833106995,
#   'valid_loss_best': False,
#   'event_lr': 0.009263200821770455},
#  {'batches': [{'train_loss': 1.0270334482192993, 'train_batch_size': 64},
#    {'train_loss': 1.0074982643127441, 'train_batch_size': 64},
#    {'train_loss': 0.9738752245903015, 'train_batch_size': 64},
#    {'train_loss': 1.0310858488082886, 'train_batch_size': 64},
#    {'train_loss': 1.0766606330871582, 'train_batch_size': 64},
#    {'train_loss': 0.9234632849693298, 'train_batch_size': 64},
#    {'train_loss': 0.970602810382843, 'train_batch_size': 64},
#    {'train_loss': 0.9583433270454407, 'train_batch_size': 64},
#    {'train_loss': 0.9216079115867615, 'train_batch_size': 64},
#    {'train_loss': 0.8334093689918518, 'train_batch_size': 64},
#    {'train_loss': 0.8926488757133484, 'train_batch_size': 60},
#    {'valid_loss': 0.5799999833106995, 'valid_batch_size': 50}],
#   'epoch': 37,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027387142181396484,
#   'train_loss': 0.9655258005005972,
#   'train_loss_best': True,
#   'valid_loss': 0.5799999833106995,
#   'valid_loss_best': False,
#   'event_lr': 0.009221639627510068},
#  {'batches': [{'train_loss': 1.0204638242721558, 'train_batch_size': 64},
#    {'train_loss': 1.0382887125015259, 'train_batch_size': 64},
#    {'train_loss': 0.9081935286521912, 'train_batch_size': 64},
#    {'train_loss': 1.0812163352966309, 'train_batch_size': 64},
#    {'train_loss': 1.051906943321228, 'train_batch_size': 64},
#    {'train_loss': 0.8722798824310303, 'train_batch_size': 64},
#    {'train_loss': 0.927900493144989, 'train_batch_size': 64},
#    {'train_loss': 0.914267361164093, 'train_batch_size': 64},
#    {'train_loss': 0.9401859045028687, 'train_batch_size': 64},
#    {'train_loss': 0.820071280002594, 'train_batch_size': 64},
#    {'train_loss': 0.8942959904670715, 'train_batch_size': 60},
#    {'valid_loss': 0.6399999856948853, 'valid_batch_size': 50}],
#   'epoch': 38,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027498960494995117,
#   'train_loss': 0.9520618748664856,
#   'train_loss_best': True,
#   'valid_loss': 0.6399999856948853,
#   'valid_loss_best': False,
#   'event_lr': 0.009179036806841345},
#  {'batches': [{'train_loss': 1.0214711427688599, 'train_batch_size': 64},
#    {'train_loss': 1.0063564777374268, 'train_batch_size': 64},
#    {'train_loss': 0.914408266544342, 'train_batch_size': 64},
#    {'train_loss': 1.0058900117874146, 'train_batch_size': 64},
#    {'train_loss': 1.056442379951477, 'train_batch_size': 64},
#    {'train_loss': 0.8538118004798889, 'train_batch_size': 64},
#    {'train_loss': 0.8993844389915466, 'train_batch_size': 64},
#    {'train_loss': 0.9044071435928345, 'train_batch_size': 64},
#    {'train_loss': 0.9276303648948669, 'train_batch_size': 64},
#    {'train_loss': 0.7982527017593384, 'train_batch_size': 64},
#    {'train_loss': 0.8800601959228516, 'train_batch_size': 60},
#    {'valid_loss': 0.6200000047683716, 'valid_batch_size': 50}],
#   'epoch': 39,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027554988861083984,
#   'train_loss': 0.9337701633998325,
#   'train_loss_best': True,
#   'valid_loss': 0.6200000047683716,
#   'valid_loss_best': False,
#   'event_lr': 0.009135402871372801},
#  {'batches': [{'train_loss': 1.0104345083236694, 'train_batch_size': 64},
#    {'train_loss': 0.9889597296714783, 'train_batch_size': 64},
#    {'train_loss': 0.8771953582763672, 'train_batch_size': 64},
#    {'train_loss': 0.951711118221283, 'train_batch_size': 64},
#    {'train_loss': 1.0409270524978638, 'train_batch_size': 64},
#    {'train_loss': 0.8642281889915466, 'train_batch_size': 64},
#    {'train_loss': 0.8995130062103271, 'train_batch_size': 64},
#    {'train_loss': 0.8681323528289795, 'train_batch_size': 64},
#    {'train_loss': 0.8967316150665283, 'train_batch_size': 64},
#    {'train_loss': 0.7825227975845337, 'train_batch_size': 64},
#    {'train_loss': 0.8703720569610596, 'train_batch_size': 60},
#    {'valid_loss': 0.5799999833106995, 'valid_batch_size': 50}],
#   'epoch': 40,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02753305435180664,
#   'train_loss': 0.9139501285552979,
#   'train_loss_best': True,
#   'valid_loss': 0.5799999833106995,
#   'valid_loss_best': False,
#   'event_lr': 0.00909074858712511},
#  {'batches': [{'train_loss': 0.9691615700721741, 'train_batch_size': 64},
#    {'train_loss': 0.9773204326629639, 'train_batch_size': 64},
#    {'train_loss': 0.8664440512657166, 'train_batch_size': 64},
#    {'train_loss': 0.9260618090629578, 'train_batch_size': 64},
#    {'train_loss': 1.027454137802124, 'train_batch_size': 64},
#    {'train_loss': 0.8354364037513733, 'train_batch_size': 64},
#    {'train_loss': 0.8858671188354492, 'train_batch_size': 64},
#    {'train_loss': 0.857736349105835, 'train_batch_size': 64},
#    {'train_loss': 0.8852685689926147, 'train_batch_size': 64},
#    {'train_loss': 0.7672321796417236, 'train_batch_size': 64},
#    {'train_loss': 0.8571050763130188, 'train_batch_size': 60},
#    {'valid_loss': 0.699999988079071, 'valid_batch_size': 50}],
#   'epoch': 41,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027920961380004883,
#   'train_loss': 0.8961388461930411,
#   'train_loss_best': True,
#   'valid_loss': 0.699999988079071,
#   'valid_loss_best': False,
#   'event_lr': 0.00904508497187473},
#  {'batches': [{'train_loss': 0.9749646782875061, 'train_batch_size': 64},
#    {'train_loss': 0.9693496227264404, 'train_batch_size': 64},
#    {'train_loss': 0.8526909351348877, 'train_batch_size': 64},
#    {'train_loss': 0.911435067653656, 'train_batch_size': 64},
#    {'train_loss': 1.026198387145996, 'train_batch_size': 64},
#    {'train_loss': 0.8242462277412415, 'train_batch_size': 64},
#    {'train_loss': 0.8553787469863892, 'train_batch_size': 64},
#    {'train_loss': 0.8542150855064392, 'train_batch_size': 64},
#    {'train_loss': 0.8802387714385986, 'train_batch_size': 64},
#    {'train_loss': 0.7349388599395752, 'train_batch_size': 64},
#    {'train_loss': 0.8457252979278564, 'train_batch_size': 60},
#    {'valid_loss': 0.7599999904632568, 'valid_batch_size': 50}],
#   'epoch': 42,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027991056442260742,
#   'train_loss': 0.8847107519422258,
#   'train_loss_best': True,
#   'valid_loss': 0.7599999904632568,
#   'valid_loss_best': False,
#   'event_lr': 0.008998423292435446},
#  {'batches': [{'train_loss': 0.9623951315879822, 'train_batch_size': 64},
#    {'train_loss': 0.9585246443748474, 'train_batch_size': 64},
#    {'train_loss': 0.8424392938613892, 'train_batch_size': 64},
#    {'train_loss': 0.8963857889175415, 'train_batch_size': 64},
#    {'train_loss': 1.014207124710083, 'train_batch_size': 64},
#    {'train_loss': 0.8141670823097229, 'train_batch_size': 64},
#    {'train_loss': 0.8487817645072937, 'train_batch_size': 64},
#    {'train_loss': 0.8419700860977173, 'train_batch_size': 64},
#    {'train_loss': 0.8724677562713623, 'train_batch_size': 64},
#    {'train_loss': 0.7288396954536438, 'train_batch_size': 64},
#    {'train_loss': 0.8426626324653625, 'train_batch_size': 60},
#    {'valid_loss': 0.7200000286102295, 'valid_batch_size': 50}],
#   'epoch': 43,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.028048038482666016,
#   'train_loss': 0.8749873907225473,
#   'train_loss_best': True,
#   'valid_loss': 0.7200000286102295,
#   'valid_loss_best': False,
#   'event_lr': 0.008950775061878444},
#  {'batches': [{'train_loss': 0.957119882106781, 'train_batch_size': 64},
#    {'train_loss': 0.951991856098175, 'train_batch_size': 64},
#    {'train_loss': 0.834334135055542, 'train_batch_size': 64},
#    {'train_loss': 0.8661130666732788, 'train_batch_size': 64},
#    {'train_loss': 1.0035910606384277, 'train_batch_size': 64},
#    {'train_loss': 0.8056438565254211, 'train_batch_size': 64},
#    {'train_loss': 0.8392423987388611, 'train_batch_size': 64},
#    {'train_loss': 0.8324281573295593, 'train_batch_size': 64},
#    {'train_loss': 0.865013837814331, 'train_batch_size': 64},
#    {'train_loss': 0.7165541052818298, 'train_batch_size': 64},
#    {'train_loss': 0.8361881375312805, 'train_batch_size': 60},
#    {'valid_loss': 0.800000011920929, 'valid_batch_size': 50}],
#   'epoch': 44,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02735304832458496,
#   'train_loss': 0.8645447986466545,
#   'train_loss_best': True,
#   'valid_loss': 0.800000011920929,
#   'valid_loss_best': False,
#   'event_lr': 0.008902152036691641},
#  {'batches': [{'train_loss': 0.9513046145439148, 'train_batch_size': 64},
#    {'train_loss': 0.9374008178710938, 'train_batch_size': 64},
#    {'train_loss': 0.8258901834487915, 'train_batch_size': 64},
#    {'train_loss': 0.8642143607139587, 'train_batch_size': 64},
#    {'train_loss': 0.9960446953773499, 'train_batch_size': 64},
#    {'train_loss': 0.7973740100860596, 'train_batch_size': 64},
#    {'train_loss': 0.8345790505409241, 'train_batch_size': 64},
#    {'train_loss': 0.8261573910713196, 'train_batch_size': 64},
#    {'train_loss': 0.8548601269721985, 'train_batch_size': 64},
#    {'train_loss': 0.7116789817810059, 'train_batch_size': 64},
#    {'train_loss': 0.8271003365516663, 'train_batch_size': 60},
#    {'valid_loss': 0.7200000286102295, 'valid_batch_size': 50}],
#   'epoch': 45,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02763080596923828,
#   'train_loss': 0.857134701524462,
#   'train_loss_best': True,
#   'valid_loss': 0.7200000286102295,
#   'valid_loss_best': False,
#   'event_lr': 0.008852566213878938},
#  {'batches': [{'train_loss': 0.9434280395507812, 'train_batch_size': 64},
#    {'train_loss': 0.9337899684906006, 'train_batch_size': 64},
#    {'train_loss': 0.8189340829849243, 'train_batch_size': 64},
#    {'train_loss': 0.8543533086776733, 'train_batch_size': 64},
#    {'train_loss': 0.9889445900917053, 'train_batch_size': 64},
#    {'train_loss': 0.7909061312675476, 'train_batch_size': 64},
#    {'train_loss': 0.8277706503868103, 'train_batch_size': 64},
#    {'train_loss': 0.821441113948822, 'train_batch_size': 64},
#    {'train_loss': 0.846698522567749, 'train_batch_size': 64},
#    {'train_loss': 0.7011296153068542, 'train_batch_size': 64},
#    {'train_loss': 0.820375382900238, 'train_batch_size': 60},
#    {'valid_loss': 0.7599999904632568, 'valid_batch_size': 50}],
#   'epoch': 46,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02749800682067871,
#   'train_loss': 0.8499655263764517,
#   'train_loss_best': True,
#   'valid_loss': 0.7599999904632568,
#   'valid_loss_best': False,
#   'event_lr': 0.008802029828000147},
#  {'batches': [{'train_loss': 0.9388363361358643, 'train_batch_size': 64},
#    {'train_loss': 0.9281914234161377, 'train_batch_size': 64},
#    {'train_loss': 0.8098211288452148, 'train_batch_size': 64},
#    {'train_loss': 0.8487876653671265, 'train_batch_size': 64},
#    {'train_loss': 0.9853389859199524, 'train_batch_size': 64},
#    {'train_loss': 0.7828390598297119, 'train_batch_size': 64},
#    {'train_loss': 0.8155734539031982, 'train_batch_size': 64},
#    {'train_loss': 0.8121256232261658, 'train_batch_size': 64},
#    {'train_loss': 0.8392355442047119, 'train_batch_size': 64},
#    {'train_loss': 0.693977415561676, 'train_batch_size': 64},
#    {'train_loss': 0.808542788028717, 'train_batch_size': 60},
# ...
#    {'train_loss': 0.36752423644065857, 'train_batch_size': 64},
#    {'train_loss': 0.518248438835144, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 185,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027339935302734375,
#   'train_loss': 0.49998379639216833,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 0.00015708419435684514},
#  {'batches': [{'train_loss': 0.5419918894767761, 'train_batch_size': 64},
#    {'train_loss': 0.5288916230201721, 'train_batch_size': 64},
#    {'train_loss': 0.5053947567939758, 'train_batch_size': 64},
#    {'train_loss': 0.5132893919944763, 'train_batch_size': 64},
#    {'train_loss': 0.6034684777259827, 'train_batch_size': 64},
#    {'train_loss': 0.44134578108787537, 'train_batch_size': 64},
#    {'train_loss': 0.48843124508857727, 'train_batch_size': 64},
#    {'train_loss': 0.478864461183548, 'train_batch_size': 64},
#    {'train_loss': 0.5129424929618835, 'train_batch_size': 64},
#    {'train_loss': 0.36745816469192505, 'train_batch_size': 64},
#    {'train_loss': 0.5181923508644104, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 186,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.028078794479370117,
#   'train_loss': 0.4999207874706813,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 0.0001381503980116172},
#  {'batches': [{'train_loss': 0.5419356226921082, 'train_batch_size': 64},
#    {'train_loss': 0.5288336277008057, 'train_batch_size': 64},
#    {'train_loss': 0.5053396821022034, 'train_batch_size': 64},
#    {'train_loss': 0.5132342576980591, 'train_batch_size': 64},
#    {'train_loss': 0.6034173965454102, 'train_batch_size': 64},
#    {'train_loss': 0.4412879943847656, 'train_batch_size': 64},
#    {'train_loss': 0.4883781373500824, 'train_batch_size': 64},
#    {'train_loss': 0.478811651468277, 'train_batch_size': 64},
#    {'train_loss': 0.5128788352012634, 'train_batch_size': 64},
#    {'train_loss': 0.3674003779888153, 'train_batch_size': 64},
#    {'train_loss': 0.5181435942649841, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 187,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027158021926879883,
#   'train_loss': 0.49986534425190515,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 0.00012041619030626336},
#  {'batches': [{'train_loss': 0.5418866872787476, 'train_batch_size': 64},
#    {'train_loss': 0.5287832617759705, 'train_batch_size': 64},
#    {'train_loss': 0.5052915811538696, 'train_batch_size': 64},
#    {'train_loss': 0.5131863355636597, 'train_batch_size': 64},
#    {'train_loss': 0.6033728718757629, 'train_batch_size': 64},
#    {'train_loss': 0.44123804569244385, 'train_batch_size': 64},
#    {'train_loss': 0.4883320927619934, 'train_batch_size': 64},
#    {'train_loss': 0.47876596450805664, 'train_batch_size': 64},
#    {'train_loss': 0.5128254294395447, 'train_batch_size': 64},
#    {'train_loss': 0.3673505485057831, 'train_batch_size': 64},
#    {'train_loss': 0.5181012749671936, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 188,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027086973190307617,
#   'train_loss': 0.4998173955508641,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 0.00010388594689117068},
#  {'batches': [{'train_loss': 0.5418446063995361, 'train_batch_size': 64},
#    {'train_loss': 0.5287398099899292, 'train_batch_size': 64},
#    {'train_loss': 0.505250096321106, 'train_batch_size': 64},
#    {'train_loss': 0.5131450891494751, 'train_batch_size': 64},
#    {'train_loss': 0.6033345460891724, 'train_batch_size': 64},
#    {'train_loss': 0.44119518995285034, 'train_batch_size': 64},
#    {'train_loss': 0.4882926642894745, 'train_batch_size': 64},
#    {'train_loss': 0.4787268340587616, 'train_batch_size': 64},
#    {'train_loss': 0.5127809643745422, 'train_batch_size': 64},
#    {'train_loss': 0.3673079311847687, 'train_batch_size': 64},
#    {'train_loss': 0.5180652737617493, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 189,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027302265167236328,
#   'train_loss': 0.49977635894502914,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 8.856374635655638e-05},
#  {'batches': [{'train_loss': 0.5418086647987366, 'train_batch_size': 64},
#    {'train_loss': 0.5287029147148132, 'train_batch_size': 64},
#    {'train_loss': 0.5052148103713989, 'train_batch_size': 64},
#    {'train_loss': 0.5131101012229919, 'train_batch_size': 64},
#    {'train_loss': 0.6033021807670593, 'train_batch_size': 64},
#    {'train_loss': 0.4411587417125702, 'train_batch_size': 64},
#    {'train_loss': 0.4882591962814331, 'train_batch_size': 64},
#    {'train_loss': 0.47869378328323364, 'train_batch_size': 64},
#    {'train_loss': 0.5127442479133606, 'train_batch_size': 64},
#    {'train_loss': 0.3672720789909363, 'train_batch_size': 64},
#    {'train_loss': 0.5180350542068481, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 190,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.026910066604614258,
#   'train_loss': 0.49974167619432724,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 7.445336922613064e-05},
#  {'batches': [{'train_loss': 0.5417786836624146, 'train_batch_size': 64},
#    {'train_loss': 0.5286719799041748, 'train_batch_size': 64},
#    {'train_loss': 0.5051853656768799, 'train_batch_size': 64},
#    {'train_loss': 0.5130810737609863, 'train_batch_size': 64},
#    {'train_loss': 0.6032751202583313, 'train_batch_size': 64},
#    {'train_loss': 0.4411284327507019, 'train_batch_size': 64},
#    {'train_loss': 0.48823145031929016, 'train_batch_size': 64},
#    {'train_loss': 0.47866639494895935, 'train_batch_size': 64},
#    {'train_loss': 0.5127142071723938, 'train_batch_size': 64},
#    {'train_loss': 0.3672425150871277, 'train_batch_size': 64},
#    {'train_loss': 0.518010139465332, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 191,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02760004997253418,
#   'train_loss': 0.49971288953508647,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 6.155829702431169e-05},
#  {'batches': [{'train_loss': 0.5417539477348328, 'train_batch_size': 64},
#    {'train_loss': 0.5286464691162109, 'train_batch_size': 64},
#    {'train_loss': 0.5051610469818115, 'train_batch_size': 64},
#    {'train_loss': 0.5130571722984314, 'train_batch_size': 64},
#    {'train_loss': 0.6032529473304749, 'train_batch_size': 64},
#    {'train_loss': 0.4411037266254425, 'train_batch_size': 64},
#    {'train_loss': 0.4882088005542755, 'train_batch_size': 64},
#    {'train_loss': 0.47864407300949097, 'train_batch_size': 64},
#    {'train_loss': 0.5126903057098389, 'train_batch_size': 64},
#    {'train_loss': 0.36721858382225037, 'train_batch_size': 64},
#    {'train_loss': 0.517989993095398, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 192,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027474164962768555,
#   'train_loss': 0.4996893889563424,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 4.988171141721231e-05},
#  {'batches': [{'train_loss': 0.5417341589927673, 'train_batch_size': 64},
#    {'train_loss': 0.5286259651184082, 'train_batch_size': 64},
#    {'train_loss': 0.5051416754722595, 'train_batch_size': 64},
#    {'train_loss': 0.5130380988121033, 'train_batch_size': 64},
#    {'train_loss': 0.6032352447509766, 'train_batch_size': 64},
#    {'train_loss': 0.4410841166973114, 'train_batch_size': 64},
#    {'train_loss': 0.4881908595561981, 'train_batch_size': 64},
#    {'train_loss': 0.47862643003463745, 'train_batch_size': 64},
#    {'train_loss': 0.5126714110374451, 'train_batch_size': 64},
#    {'train_loss': 0.36719968914985657, 'train_batch_size': 64},
#    {'train_loss': 0.517974317073822, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 193,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027308940887451172,
#   'train_loss': 0.49967072657176426,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 3.9426493427611173e-05},
#  {'batches': [{'train_loss': 0.5417184233665466, 'train_batch_size': 64},
#    {'train_loss': 0.5286099910736084, 'train_batch_size': 64},
#    {'train_loss': 0.5051265358924866, 'train_batch_size': 64},
#    {'train_loss': 0.5130231976509094, 'train_batch_size': 64},
#    {'train_loss': 0.6032214760780334, 'train_batch_size': 64},
#    {'train_loss': 0.4410686790943146, 'train_batch_size': 64},
#    {'train_loss': 0.48817700147628784, 'train_batch_size': 64},
#    {'train_loss': 0.47861286997795105, 'train_batch_size': 64},
#    {'train_loss': 0.512657105922699, 'train_batch_size': 64},
#    {'train_loss': 0.36718523502349854, 'train_batch_size': 64},
#    {'train_loss': 0.5179623365402222, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 194,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027230262756347656,
#   'train_loss': 0.4996562474114554,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 3.0195222724102018e-05},
#  {'batches': [{'train_loss': 0.5417066216468811, 'train_batch_size': 64},
#    {'train_loss': 0.528597891330719, 'train_batch_size': 64},
#    {'train_loss': 0.5051149725914001, 'train_batch_size': 64},
#    {'train_loss': 0.5130118131637573, 'train_batch_size': 64},
#    {'train_loss': 0.603210985660553, 'train_batch_size': 64},
#    {'train_loss': 0.44105684757232666, 'train_batch_size': 64},
#    {'train_loss': 0.4881662428379059, 'train_batch_size': 64},
#    {'train_loss': 0.4786023199558258, 'train_batch_size': 64},
#    {'train_loss': 0.512645959854126, 'train_batch_size': 64},
#    {'train_loss': 0.36717402935028076, 'train_batch_size': 64},
#    {'train_loss': 0.5179528594017029, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 195,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02743816375732422,
#   'train_loss': 0.49964511905397685,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 2.2190176984600013e-05},
#  {'batches': [{'train_loss': 0.5416973233222961, 'train_batch_size': 64},
#    {'train_loss': 0.5285884141921997, 'train_batch_size': 64},
#    {'train_loss': 0.5051060914993286, 'train_batch_size': 64},
#    {'train_loss': 0.5130031108856201, 'train_batch_size': 64},
#    {'train_loss': 0.6032029390335083, 'train_batch_size': 64},
#    {'train_loss': 0.4410480260848999, 'train_batch_size': 64},
#    {'train_loss': 0.48815834522247314, 'train_batch_size': 64},
#    {'train_loss': 0.47859448194503784, 'train_batch_size': 64},
#    {'train_loss': 0.5126379728317261, 'train_batch_size': 64},
#    {'train_loss': 0.36716586351394653, 'train_batch_size': 64},
#    {'train_loss': 0.5179460644721985, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 196,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.026996850967407227,
#   'train_loss': 0.49963675464902607,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 1.5413331334360176e-05},
#  {'batches': [{'train_loss': 0.5416907668113708, 'train_batch_size': 64},
#    {'train_loss': 0.5285818576812744, 'train_batch_size': 64},
#    {'train_loss': 0.5050998330116272, 'train_batch_size': 64},
#    {'train_loss': 0.5129970908164978, 'train_batch_size': 64},
#    {'train_loss': 0.6031972765922546, 'train_batch_size': 64},
#    {'train_loss': 0.4410419762134552, 'train_batch_size': 64},
#    {'train_loss': 0.48815295100212097, 'train_batch_size': 64},
#    {'train_loss': 0.47858935594558716, 'train_batch_size': 64},
#    {'train_loss': 0.5126327872276306, 'train_batch_size': 64},
#    {'train_loss': 0.3671606779098511, 'train_batch_size': 64},
#    {'train_loss': 0.5179417729377747, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 197,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02735161781311035,
#   'train_loss': 0.4996310843740191,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 9.866357858642203e-06},
#  {'batches': [{'train_loss': 0.5416866540908813, 'train_batch_size': 64},
#    {'train_loss': 0.5285776257514954, 'train_batch_size': 64},
#    {'train_loss': 0.5050960183143616, 'train_batch_size': 64},
#    {'train_loss': 0.5129933953285217, 'train_batch_size': 64},
#    {'train_loss': 0.6031939387321472, 'train_batch_size': 64},
#    {'train_loss': 0.44103822112083435, 'train_batch_size': 64},
#    {'train_loss': 0.48814961314201355, 'train_batch_size': 64},
#    {'train_loss': 0.4785863161087036, 'train_batch_size': 64},
#    {'train_loss': 0.5126296281814575, 'train_batch_size': 64},
#    {'train_loss': 0.36715754866600037, 'train_batch_size': 64},
#    {'train_loss': 0.5179392695426941, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 198,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.027408838272094727,
#   'train_loss': 0.4996276136807033,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 5.5506251901504804e-06},
#  {'batches': [{'train_loss': 0.5416842103004456, 'train_batch_size': 64},
#    {'train_loss': 0.5285753607749939, 'train_batch_size': 64},
#    {'train_loss': 0.5050938129425049, 'train_batch_size': 64},
#    {'train_loss': 0.5129913687705994, 'train_batch_size': 64},
#    {'train_loss': 0.6031920909881592, 'train_batch_size': 64},
#    {'train_loss': 0.44103625416755676, 'train_batch_size': 64},
#    {'train_loss': 0.4881478548049927, 'train_batch_size': 64},
#    {'train_loss': 0.4785846471786499, 'train_batch_size': 64},
#    {'train_loss': 0.5126280188560486, 'train_batch_size': 64},
#    {'train_loss': 0.36715593934059143, 'train_batch_size': 64},
#    {'train_loss': 0.5179380774497986, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 199,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02704477310180664,
#   'train_loss': 0.49962573766708374,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 2.467198171341999e-06},
#  {'batches': [{'train_loss': 0.5416831970214844, 'train_batch_size': 64},
#    {'train_loss': 0.5285742878913879, 'train_batch_size': 64},
#    {'train_loss': 0.5050928592681885, 'train_batch_size': 64},
#    {'train_loss': 0.5129905343055725, 'train_batch_size': 64},
#    {'train_loss': 0.6031913161277771, 'train_batch_size': 64},
#    {'train_loss': 0.4410354495048523, 'train_batch_size': 64},
#    {'train_loss': 0.4881472885608673, 'train_batch_size': 64},
#    {'train_loss': 0.4785841703414917, 'train_batch_size': 64},
#    {'train_loss': 0.5126276016235352, 'train_batch_size': 64},
#    {'train_loss': 0.36715564131736755, 'train_batch_size': 64},
#    {'train_loss': 0.517937958240509, 'train_batch_size': 60},
#    {'valid_loss': 0.8199999928474426, 'valid_batch_size': 50}],
#   'epoch': 200,
#   'train_batch_count': 11,
#   'valid_batch_count': 1,
#   'dur': 0.02708888053894043,
#   'train_loss': 0.49962506805147444,
#   'train_loss_best': True,
#   'valid_loss': 0.8199999928474426,
#   'valid_loss_best': False,
#   'event_lr': 6.168375916970613e-07}]

# %%
train_loss = history[:, 'train_loss']
plt.plot(train_loss)

# %%
proba = net.predict_annotator_perf(X_test)
print(proba)
# Out:
# [[0.1857719  0.1857719  0.1857719  ... 0.1857719  0.1857719  0.1857719 ]
#  [0.17243657 0.17243657 0.17243657 ... 0.17243657 0.17243657 0.17243657]
#  [0.1862333  0.1862333  0.1862333  ... 0.1862333  0.1862333  0.1862333 ]
#  ...
#  [0.11989452 0.11989452 0.11989452 ... 0.11989452 0.11989452 0.11989452]
#  [0.18713151 0.18713151 0.18713151 ... 0.18713151 0.18713151 0.18713151]
#  [0.18625921 0.18625921 0.18625921 ... 0.18625921 0.18625921 0.18625921]]
